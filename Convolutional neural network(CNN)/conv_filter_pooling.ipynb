# %% [markdown]
# # Lets see the img!

# %%
from keras.layers import Convolution2D, MaxPooling2D, Activation
from keras.models import Sequential

import numpy as np
import matplotlib.pyplot as plt
import cv2  # only used for loading the image, you can use anything that returns the image as a np.ndarray

test = cv2.imread('d:\\data\\test.png')
#test = cv2.cvtColor(test, cv2.COLOR_BGR2GRAY)

plt.imshow(test)
print(test.shape)
# Out:
# (116, 116, 3)

# %% [markdown]
# # Lets create a model with 1 Convolutional layer

# %%
model = Sequential()
model.add(Convolution2D(3,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=test.shape))
# Out:
# C:\Users\baek\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (3, 3), input_shape=(116, 116,...)`
#   """

# %%
test_batch = np.expand_dims(test,axis=0)

# here we get rid of that added dimension and plot the image
def visualize_test(model, test):
    # Keras expects batches of images, so we have to add a dimension to trick it into being nice
    test_batch = np.expand_dims(test,axis=0)
    conv_test = model.predict(test_batch)
    conv_test = np.squeeze(conv_test, axis=0)
    print (conv_test.shape)
    plt.imshow(conv_test)

# %%
visualize_test(model, test)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (114, 114, 3)

# %% [markdown]
# # 10x10 Kernel Conv

# %%
model = Sequential()
model.add(Convolution2D(3,    # number of filter layers
                        10,    # y dimension of kernel (we're going for a 3x3 kernel)
                        10,    # x dimension of kernel
                        input_shape=test.shape))


visualize_test(model, test)
# Out:
# C:\Users\baek\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (10, 10), input_shape=(116, 116,...)`
#   """
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (107, 107, 3)

# %% [markdown]
# # img with 1 filter

# %%
# Note: matplot lib is pretty inconsistent with how it plots these weird cat arrays.
# Try running them a couple of times if the output doesn't quite match the blog post results.
def nice_test_printer(model, test):
    '''prints the cat as a 2d array'''
    cat_batch = np.expand_dims(test,axis=0)
    conv_test2 = model.predict(test_batch)

    conv_test2 = np.squeeze(conv_test2, axis=0)
    print(conv_test2.shape)
    conv_test2 = conv_test2.reshape(conv_test2.shape[:2])

    print(conv_test2.shape)
    plt.imshow(conv_test2)

# %%
model = Sequential()
model.add(Convolution2D(1,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=test.shape))

# Keras expects batches of images, so we have to add a dimension to trick it into being nice
nice_test_printer(model, test)
# Out:
# C:\Users\baek\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(116, 116,...)`
#   """
# (114, 114, 1)
# (114, 114)

# %%
# 15x15 kernel size
model = Sequential()
model.add(Convolution2D(1,    # number of filter layers
                        15,    # y dimension of kernel (we're going for a 3x3 kernel)
                        15,    # x dimension of kernel
                        input_shape=test.shape))

nice_test_printer(model, test)
# Out:
# C:\Users\baek\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (15, 15), input_shape=(116, 116,...)`
# (102, 102, 1)
# (102, 102)

# %% [markdown]
# # Lets add a relu activation

# %%
model = Sequential()
model.add(Convolution2D(1,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=test.shape))
# Lets add a new activation layer!
model.add(Activation('relu'))

nice_test_printer(model, test)
# Out:
# C:\Users\baek\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(116, 116,...)`
#   """
# (114, 114, 1)
# (114, 114)

# %%
model = Sequential()
model.add(Convolution2D(3,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=test.shape))
# Lets add a new activation layer!
model.add(Activation('relu'))

visualize_test(model, test)
# Out:
# C:\Users\baek\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (3, 3), input_shape=(116, 116,...)`
#   """
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (114, 114, 3)

# %% [markdown]
# # Max Pooling

# %%
model = Sequential()
model.add(Convolution2D(3,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=test.shape))
# Lets add a new max pooling layer!
model.add(MaxPooling2D(pool_size=(5,5)))

# nice_cat_printer(model, cat)
visualize_test(model, test)
# Out:
# C:\Users\baek\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (3, 3), input_shape=(116, 116,...)`
#   """
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (22, 22, 3)

# %%
model = Sequential()
model.add(Convolution2D(1,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=test.shape))
# Lets activate then pool!
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(5,5)))

nice_test_printer(model, test)
# Out:
# C:\Users\baek\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(116, 116,...)`
#   """
# (22, 22, 1)
# (22, 22)

# %% [markdown]
# # Activation then pooling

# %%
model = Sequential()
model.add(Convolution2D(1,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=test.shape))
# Lets activate then pool!
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(5,5)))

nice_test_printer(model, test)
# Out:
# C:\Users\baek\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(116, 116,...)`
#   """
# (22, 22, 1)
# (22, 22)

# %%
model = Sequential()
model.add(Convolution2D(3,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=test.shape))
# Lets activate then pool!
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(5,5)))

visualize_test(model, test)
# Out:
# C:\Users\baek\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (3, 3), input_shape=(116, 116,...)`
#   """
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (22, 22, 3)

# %% [markdown]
# # img after the convolutional and pooling stages of LeNet

# %%
# 1 filter in each conv layer for pretty printing
model = Sequential()
model.add(Convolution2D(1,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=test.shape))
# Lets activate then pool!
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3)))
model.add(Convolution2D(1,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=test.shape))
# Lets activate then pool!
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3)))

nice_test_printer(model, test)
# Out:
# C:\Users\baek\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(116, 116,...)`
#
# C:\Users\baek\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(116, 116,...)`
#   del sys.path[0]
# (12, 12, 1)
# (12, 12)

# %%
# 3 filters in conv1, then 1 filter for pretty printing
model = Sequential()
model.add(Convolution2D(3,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=test.shape))
# Lets activate then pool!
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3)))
model.add(Convolution2D(1,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=test.shape))
# Lets activate then pool!
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

nice_test_printer(model, test)
# Out:
# C:\Users\baek\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (3, 3), input_shape=(116, 116,...)`
#
# C:\Users\baek\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(116, 116,...)`
#   del sys.path[0]
# (18, 18, 1)
# (18, 18)

# %%
# 3 filters in both conv layers
model = Sequential()
model.add(Convolution2D(3,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=test.shape))
# Lets activate then pool!
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3)))
model.add(Convolution2D(3,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=test.shape))
# Lets activate then pool!
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

visualize_test(model, test)
# Out:
# C:\Users\baek\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (3, 3), input_shape=(116, 116,...)`
#
# C:\Users\baek\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (3, 3), input_shape=(116, 116,...)`
#   del sys.path[0]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (18, 18, 3)
